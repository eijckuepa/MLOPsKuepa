# %% [markdown]
# <a href="https://colab.research.google.com/github/eijckuepa/MLOPsKuepa/blob/main/TimeSeriesAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# %%capture
# !pip install pandas ai
# !pip install requests
# !pip install polars

# %% [markdown]
# ## Índice temático
#
# *   El ciclo de vida de los modelos en ML
# *   Prácticas recomendadas en MLOps
# *   Herramientas comunes en MLOps
# *   Demostración práctica

# %% [markdown]
# ### Control de versiones
# se encarga de llevar un control de archivos y actualizaciones con lineamientos específicos y enfocados a que el codigo de la implementación y la reproducibilidad estén aseguradas.

# %% [markdown]
# #sección 2

# %% [markdown]
# ![image.png](data:image/png;base64,...)
